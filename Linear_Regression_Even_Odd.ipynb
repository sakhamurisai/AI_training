# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import mean_absolute_error, r2_score

# %%
train_numbers = list(range(1000000))
test_numbers = list(range(100,120))

# %%
X = np.array([[n] for n in train_numbers])
Y = np.array([0 if n%2 else 1 for n in train_numbers])

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test)

# %%
print(prediction)
# Out:
# [0.50012602 0.49984972 0.49997187 ... 0.4998123  0.50033765 0.49997958]

# %%
print(Y_test)
# Out:
# [1 1 1 ... 0 0 0]

# %%
plt.figure(figsize=(7,6))
plt.plot(Y_test, label='Actual', marker='o')
plt.plot(prediction, label='Predicted', marker='x')
plt.title("House income Prediction — Linear Regression")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
mae = mean_absolute_error(Y_test, prediction)
r2 = r2_score(Y_test, prediction)
print(mae,r2)
# Out:
# 0.50000029889853 -1.8484097215054618e-06

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 accuracy = accuracy_score(Y_test,prediction)
#       2 print(accuracy)
#
# File D:\Projects\AI\SandBox\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
# ...
