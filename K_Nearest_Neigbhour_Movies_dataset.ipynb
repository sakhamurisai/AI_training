# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv("D:\\Projects\\working_data\\large_movie_ratings_dataset.csv")

# %%
print(df.head(5))
# Out:
#    user_id                  moviename  rating
# 0      861  Mission Lord of the Rings       4
# 1     3773            Legend of Joker       3
# 2     3093               Star Titanic       5
# 3      467             Mission Batman       4
# 4     4427                    A Joker       5

# %%
# Assuming 'df' is your DataFrame
df.drop_duplicates(subset=['user_id'], keep='first', inplace=True)

# %%
pivot_df = df.pivot(index = 'user_id', columns = 'moviename', values = 'rating')

# %%
X = df['moviename'].astype(str).tolist()

# %%
vectorizer = CountVectorizer()

# %%
X = vectorizer.fit_transform(X)

# %%
Y = df['rating']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
model = KNeighborsClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
prediction = model.predict(X_test)

# %%
accuracy_score(Y_test, prediction)
# Out:
# 0.237
