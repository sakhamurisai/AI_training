# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %%
digits = load_digits()

# %%
X = digits.data
Y = digits.target

# %%
print(X.shape)
# Out:
# (1797, 64)

# %%
print(Y.shape)
# Out:
# (1797,)

# %%
print(Y)
# Out:
# [0 1 2 ... 8 9 8]

# %%
X_train, X_test , Y_train , Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
for kernel in  ['linear', 'poly', 'rbf', 'sigmoid']:
    model = SVC(kernel=kernel)
    model.fit(X_train, Y_train)        # ✅ y must be 1D here
    prediction = model.predict(X_test)
    print(f"{kernel} model {accuracy_score(Y_test, prediction)}")
# Out:
# linear model 0.9666666666666667
# poly model 0.9861111111111112
# rbf model 0.9916666666666667
# sigmoid model 0.8805555555555555

# %%
plt.figure(figsize=(10,10))
plt.scatter(Y_test,prediction)
plt.show()
